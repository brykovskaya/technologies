# %% [markdown]
# как применять Python в e-commerce аналитике.
# основная ценность вебинара - собрать данные.
# вебинар 21.07.25 Симулятив Андрон Алексанян
# ссылка но [гугл_коллаб](https://colab.research.google.com/drive/1HVyMnQszohWeTxtlW606b1pl693egu4S?usp=sharing)

# %% [markdown]
# этот кейс с поисковым движком WB
# поищем сырые данные

# %% [markdown]
# ![](images/0001.png)

# %%
# import pandas as pd
import requests
from datetime import datetime

# %%
page = 1

query = 'лонгслив женский оверсайз'
res = requests.get(f"https://search.wb.ru/exactmatch/ru/female/v9/search?ab_testing=false&appType=64&curr=rub&dest=123585762&hide_dtype=13&lang=ru&page={page}&query={query}&resultset=catalog&sort=popular")

# %%
# мешает - поэтому закоммент
# res.json()

# %%
arr = []

# %%
query_list = ['лонгслив женский оверсайз',
             'лонгслив женский']
max_page = 3
brand = 'ТЕЛОДВИЖЕНИЯ'

for query in query_list:
    for page in range(1, max_page +1):
        res = requests.get(f"https://search.wb.ru/exactmatch/ru/female/v9/search?ab_testing=false&appType=64&curr=rub&dest=123585762&hide_dtype=13&lang=ru&page={page}&query={query}&resultset=catalog&sort=popular")
        for card in res.json()['data']['products']:
            if card.get('log') and card['brand'] == brand:
                arr.append([
                    card['log']['position'],
                    card['log']['promoPosition'],
                    datetime.now(),
                    query,
                    card['name']
                    ])
                # print(card['log'])
        # print(f"query:{query}, page: {page}")

# %%
# список карточек
# res.json()['data']['products'][1]['log']

# %%
import pandas as pd
df = pd.DataFrame(arr)
df.columns = ['position', 'promo_position', 'created_at', 'query', 'name']
df
# Out:
#     position  promo_position                 created_at  \
# 0        364              26 2025-07-21 19:47:54.407636
# 1        296              60 2025-07-21 19:47:54.407636
# 2        298              61 2025-07-21 19:47:54.407636
# 3        297              62 2025-07-21 19:47:54.407636
# 4        364              66 2025-07-21 19:47:54.407636
# 5        324              74 2025-07-21 19:47:54.407636
# 6        333              75 2025-07-21 19:47:54.407636
# 7        334              78 2025-07-21 19:47:54.407636
# 8        339              86 2025-07-21 19:47:54.407636
# 9        351              87 2025-07-21 19:47:54.407636
# 10       348              88 2025-07-21 19:47:54.407636
# 11       642             131 2025-07-21 19:47:55.503156
# 12       688             132 2025-07-21 19:47:55.503156
# 13       892             154 2025-07-21 19:47:55.503156
# 14      1059             165 2025-07-21 19:47:55.503156
# 15       710              38 2025-07-21 19:47:58.926327
# 16       754             243 2025-07-21 19:48:01.212393
# 17      4636             264 2025-07-21 19:48:01.212393
# 18      1010             293 2025-07-21 19:48:01.212393
#
#                         query  \
# 0   лонгслив женский оверсайз
# 1   лонгслив женский оверсайз
# 2   лонгслив женский оверсайз
# 3   лонгслив женский оверсайз
# 4   лонгслив женский оверсайз
# 5   лонгслив женский оверсайз
# 6   лонгслив женский оверсайз
# 7   лонгслив женский оверсайз
# 8   лонгслив женский оверсайз
# 9   лонгслив женский оверсайз
# 10  лонгслив женский оверсайз
# 11  лонгслив женский оверсайз
# 12  лонгслив женский оверсайз
# 13  лонгслив женский оверсайз
# 14  лонгслив женский оверсайз
# 15           лонгслив женский
# 16           лонгслив женский
# 17           лонгслив женский
# 18           лонгслив женский
#
#                                                  name
# 0         Лонгслив женский оверсайз с длинным рукавом
# 1         Лонгслив женский оверсайз с длинным рукавом
# 2         Лонгслив женский оверсайз с длинным рукавом
# 3         Лонгслив женский оверсайз с длинным рукавом
# 4                Лонгслив женский оверсайз набор 2 шт
# 5         Лонгслив женский оверсайз с длинным рукавом
# 6       Лонгслив свободный оверсайз с длинным рукавом
# 7         Лонгслив женский оверсайз с длинным рукавом
# 8         Лонгслив женский оверсайз с длинным рукавом
# 9                Лонгслив женский оверсайз набор 2 шт
# 10        Лонгслив женский оверсайз с длинным рукавом
# 11      Лонгслив свободный оверсайз с длинным рукавом
# 12        Лонгслив женский оверсайз с длинным рукавом
# 13  Лонгслив свободный оверсайз с принтом The Move...
# 14  Лонгслив свободный оверсайз с принтом INNER ST...
# 15        Лонгслив женский оверсайз с длинным рукавом
# 16      Лонгслив свободный оверсайз с длинным рукавом
# 17                              Лонгслив поло женский
# 18        Лонгслив женский оверсайз с длинным рукавом

# %%
df['dif'] = df['position'] - df['promo_position']
df['hour'] = df['created_at'].dt.hour
df['hour'] = df['created_at'].dt.day
df
# Out:
#     position  promo_position                 created_at  \
# 0        364              26 2025-07-21 19:47:54.407636
# 1        296              60 2025-07-21 19:47:54.407636
# 2        298              61 2025-07-21 19:47:54.407636
# 3        297              62 2025-07-21 19:47:54.407636
# 4        364              66 2025-07-21 19:47:54.407636
# 5        324              74 2025-07-21 19:47:54.407636
# 6        333              75 2025-07-21 19:47:54.407636
# 7        334              78 2025-07-21 19:47:54.407636
# 8        339              86 2025-07-21 19:47:54.407636
# 9        351              87 2025-07-21 19:47:54.407636
# 10       348              88 2025-07-21 19:47:54.407636
# 11       642             131 2025-07-21 19:47:55.503156
# 12       688             132 2025-07-21 19:47:55.503156
# 13       892             154 2025-07-21 19:47:55.503156
# 14      1059             165 2025-07-21 19:47:55.503156
# 15       710              38 2025-07-21 19:47:58.926327
# 16       754             243 2025-07-21 19:48:01.212393
# 17      4636             264 2025-07-21 19:48:01.212393
# 18      1010             293 2025-07-21 19:48:01.212393
#
#                         query  \
# 0   лонгслив женский оверсайз
# 1   лонгслив женский оверсайз
# 2   лонгслив женский оверсайз
# 3   лонгслив женский оверсайз
# 4   лонгслив женский оверсайз
# 5   лонгслив женский оверсайз
# 6   лонгслив женский оверсайз
# 7   лонгслив женский оверсайз
# 8   лонгслив женский оверсайз
# 9   лонгслив женский оверсайз
# 10  лонгслив женский оверсайз
# 11  лонгслив женский оверсайз
# 12  лонгслив женский оверсайз
# 13  лонгслив женский оверсайз
# 14  лонгслив женский оверсайз
# 15           лонгслив женский
# 16           лонгслив женский
# 17           лонгслив женский
# 18           лонгслив женский
#
#                                                  name   dif  hour
# 0         Лонгслив женский оверсайз с длинным рукавом   338    21
# 1         Лонгслив женский оверсайз с длинным рукавом   236    21
# 2         Лонгслив женский оверсайз с длинным рукавом   237    21
# 3         Лонгслив женский оверсайз с длинным рукавом   235    21
# 4                Лонгслив женский оверсайз набор 2 шт   298    21
# 5         Лонгслив женский оверсайз с длинным рукавом   250    21
# 6       Лонгслив свободный оверсайз с длинным рукавом   258    21
# 7         Лонгслив женский оверсайз с длинным рукавом   256    21
# 8         Лонгслив женский оверсайз с длинным рукавом   253    21
# 9                Лонгслив женский оверсайз набор 2 шт   264    21
# 10        Лонгслив женский оверсайз с длинным рукавом   260    21
# 11      Лонгслив свободный оверсайз с длинным рукавом   511    21
# 12        Лонгслив женский оверсайз с длинным рукавом   556    21
# 13  Лонгслив свободный оверсайз с принтом The Move...   738    21
# 14  Лонгслив свободный оверсайз с принтом INNER ST...   894    21
# 15        Лонгслив женский оверсайз с длинным рукавом   672    21
# 16      Лонгслив свободный оверсайз с длинным рукавом   511    21
# 17                              Лонгслив поло женский  4372    21
# 18        Лонгслив женский оверсайз с длинным рукавом   717    21

# %%
df1 = df[df['name'] == 'Лонгслив женский оверсайз с длинным рукавом']
df1
# Out:
#     position  promo_position                 created_at  \
# 0        364              26 2025-07-21 19:47:54.407636
# 1        296              60 2025-07-21 19:47:54.407636
# 2        298              61 2025-07-21 19:47:54.407636
# 3        297              62 2025-07-21 19:47:54.407636
# 5        324              74 2025-07-21 19:47:54.407636
# 7        334              78 2025-07-21 19:47:54.407636
# 8        339              86 2025-07-21 19:47:54.407636
# 10       348              88 2025-07-21 19:47:54.407636
# 12       688             132 2025-07-21 19:47:55.503156
# 15       710              38 2025-07-21 19:47:58.926327
# 18      1010             293 2025-07-21 19:48:01.212393
#
#                         query                                         name  \
# 0   лонгслив женский оверсайз  Лонгслив женский оверсайз с длинным рукавом
# 1   лонгслив женский оверсайз  Лонгслив женский оверсайз с длинным рукавом
# 2   лонгслив женский оверсайз  Лонгслив женский оверсайз с длинным рукавом
# 3   лонгслив женский оверсайз  Лонгслив женский оверсайз с длинным рукавом
# 5   лонгслив женский оверсайз  Лонгслив женский оверсайз с длинным рукавом
# 7   лонгслив женский оверсайз  Лонгслив женский оверсайз с длинным рукавом
# 8   лонгслив женский оверсайз  Лонгслив женский оверсайз с длинным рукавом
# 10  лонгслив женский оверсайз  Лонгслив женский оверсайз с длинным рукавом
# 12  лонгслив женский оверсайз  Лонгслив женский оверсайз с длинным рукавом
# 15           лонгслив женский  Лонгслив женский оверсайз с длинным рукавом
# 18           лонгслив женский  Лонгслив женский оверсайз с длинным рукавом
#
#     dif  hour
# 0   338    21
# 1   236    21
# 2   237    21
# 3   235    21
# 5   250    21
# 7   256    21
# 8   253    21
# 10  260    21
# 12  556    21
# 15  672    21
# 18  717    21

# %%
pd.pivot_table(
    df1,
    index='query',
    columns ='hour',
    values='promo_position',
    aggfunc='mean'
)
# Out:
# hour                               21
# query
# лонгслив женский           165.500000
# лонгслив женский оверсайз   74.111111

# %%
import matplotlib.pyplot as plt
plt.plot(df1['position']);
