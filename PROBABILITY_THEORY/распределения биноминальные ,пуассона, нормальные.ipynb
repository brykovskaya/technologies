# %% [markdown]
# ## Эксперимент Бернулли
#  испытание с двумя исходами называют экспериментом (испытанием) Бернулли. Обычно один из исходов называют успехом, а второй, соответственно, неудачей.
#
#  Вероятность успеха обычно обозначают p. По определению вероятности это значение лежит в диапазоне от
# 0 до 1. Вероятность неудачи равна 1−p, поскольку сумма вероятностей обоих исходов эксперимента равна единице.
#  ![image.png](attachment:image.png)
#   Обычно единицей обозначают результат эксперимента, принятый за успех, а нулём — неудачу.
# Практическое значение имеет не только эксперимент Бернулли, но и серия таких экспериментов.

# %% [markdown]
# ### Биномиальный эксперимент
# Биномиальный эксперимент — это эксперимент, в котором подряд проводят несколько одинаковых и независимых друг от друга испытаний Бернулли. Под независимостью понимают то же, что и в теории вероятностей: исход одного эксперимента не влияет на вероятности исходов другого.
# например:
#  - Пользователи кликают по баннеру. Каждый пользователь может попасть по баннеру, а может промахнуться.
#  - Завод производит детали. Каждая деталь может оказаться бракованной или исправной — это эксперимент Бернулли.
#  - Питон в питонопитомнике вырастает добрым или злым — это испытание Бернулли

# %% [markdown]
# #### Расчёт вероятности определённого порядка успехов и неуспехов
# ❕ Если события независимы, вероятность того, что они произойдут вместе, равна произведению их вероятностей.
#
# В биномиальном эксперименте исходы независимы, значит, вероятность конкретной комбинации успехов и неудач равна произведению их вероятностей.
#
# Рассмотрим пример с питонами. Пусть у нас есть три питона. Нас интересует вероятность того, что первые двое из них окажутся добрыми, а последний будет злым.   Пусть вероятность того, что питон добрый p=0.9, тогда вероятность того, что питон перешёл на тёмную сторону, равна p-0.9=0.1
#
#  Вычислим вероятность комбинации «успех, успех, неудача»:

# %%
p = 0.9 # вероятность, что питон добрый
prob = (1-p) * p * (1 - p)
print('вероятность комбинации «успех, успех, неудача»:', prob)
print(f'Вероятность, что в тройке питонов случится именно такой порядок:\n\
два первых добрых, а последний злой равна {round(prob * 100, 2)} %')
# Out:
# вероятность комбинации «успех, успех, неудача»: 0.008999999999999996
# Вероятность, что в тройке питонов случится именно такой порядок:
# два первых добрых, а последний злой равна 0.9 %

# %% [markdown]
#  задача . Пусть вероятность того, что питон добрый p=0.9, тогда вероятность того, что питон перешёл на тёмную сторону, равна p-0.9=0.1
#  Возьмём двух случайных питонов: их доброта и злость не зависят друг от друга. Какова вероятность, что один из них будет добрым, а другой — злым?

# %%
p = 0.9 # вероятность, что питон добрый
prob = p * (1-p) * 2 # Учитывать комбинации «злой-добрый» и «добрый-злой» нужно
print('Вероятность два исхода: «добрый-злой» и «злой-добрый»:', prob)
print(f'Вероятность, что в двойке питонов случится такие исходы:\
«добрый-злой» и «злой-добрый»  {round(prob * 100, 2)} %')
# Out:
# Вероятность два исхода: «добрый-злой» и «злой-добрый»: 0.17999999999999997
# Вероятность, что в двойке питонов случится такие исходы:«добрый-злой» и «злой-добрый»  18.0 %

# %% [raw]
# Какова вероятность, что первый питон злой, а второй — добрый?» — то решением был бы всего один исход.

# %%
p = 0.9 # вероятность, что питон добрый
prob = p * (1-p) #Учитывать комбинации «злой-добрый» и «добрый-злой» не нужно
print('Вероятность исхода: первый питон злой, а второй — добрый:', prob)
print(f'Вероятность, чтослучится именно такой порядок:\n\
первый питон злой, а второй — добрый равна {round(prob * 100, 2)} %')
# Out:
# Вероятность исхода: первый питон злой, а второй — добрый: 0.08999999999999998
# Вероятность, чтослучится именно такой порядок:
# первый питон злой, а второй — добрый равна 9.0 %

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
p = 0.75 # вероятность, что питон с голубыми глазами, остальные с зелеными
prob = (1-p)*(1-p) #Учитывать комбинации двух питонов зеленый зеленый
print('Вероятность исхода: первый питон c зелеными глазами, второй — c зелеными глазами:', prob)
print(f'Вероятность, чтослучится именно такой порядок:\n\
первый питон c зелеными глазами, второй — c зелеными глазами равна {round(prob * 100, 2)} %')
# Out:
# Вероятность исхода: первый питон c зелеными глазами, второй — c зелеными глазами: 0.0625
# Вероятность, чтослучится именно такой порядок:
# первый питон c зелеными глазами, второй — c зелеными глазами равна 6.25 %

# %% [markdown]
# #### Распределение вероятностей биномиального эксперимента с двумя испытаниями по схеме Бернулли
# В задачах с биномиальным экспериментом определяют случайную величину «количество успехов» и строят для неё распределение вероятностей.
#
# Например, в задаче о злых и добрых питонах случайная величина «количество злых питонов из двух выбранных случайно» принимает значения 0, 1 или 2. По условию вероятность того, что питон добрый p=0.9, тогда вероятность того, что питон перешёл на тёмную сторону, равна p-0.9=0.1
#
# Для случайной величины «количество злых питонов из двух выбранных случайно» получится такая таблица:
# 0 -оба добрых 0,9*0,9=0,81=81%, 1 -первый добрый второй злой или первый злой, второй добрый = 0,1*0,9 * 2 =0.18=18%, 2- два злых 0,1*0,1= 0,01=1%:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Биномиальное распределение
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 💡 Случайная величина распределена биномиально, если:
# Проводится фиксированное число попыток n.
# Каждая попытка — простой эксперимент Бернулли ровно с двумя исходами.
# Вероятность успеха p одинакова для всех n попыток.
# Попытки независимы между собой.
#
#
# n предполагает конечное количество попыток. Если устремить n к бесконечности, а вероятность успеха
# p к нулю, получится другое распределение.
# ![image-2.png](attachment:image-2.png)

# %%
from matplotlib import pyplot as plt
from math import factorial

n = 5 # количество попыток
p = 0.5 # вероятность успеха

distr = []

for k in range(0, n + 1):
    choose = factorial(n) / (factorial(k) * factorial(n - k))
    prob = choose * p**k * (1 - p)**(n - k) 
    distr.append(prob)
    
plt.bar(range(0, n + 1), distr);

# %% [markdown]
# График действительно симметричный.
# ![image.png](attachment:image.png)

# %%
from matplotlib import pyplot as plt
from math import factorial

n = 25 # количество попыток
p = 0.5 # вероятность успеха

distr = []

for k in range(0, n + 1):
    choose = factorial(n) / (factorial(k) * factorial(n - k))
    prob = choose * p**k * (1 - p)**(n - k) 
    distr.append(prob)
    
plt.bar(range(0, n + 1), distr);

# %% [markdown]
# Этот график тоже симметричный.
# ![image.png](attachment:image.png)

# %%
from matplotlib import pyplot as plt
from math import factorial

n = 30 # количество попыток
p = 0.07 # вероятность успеха

distr = []

for k in range(0, n + 1):
    choose = factorial(n) / (factorial(k) * factorial(n - k))
    prob = choose * p**k * (1 - p)**(n - k) 
    distr.append(prob)
    
plt.bar(range(0, n + 1), distr);

# %% [markdown]
# В коде ниже мы используем метод binom.pmf() из модуля scipy.stats. Он помогает получить вероятности биномиального распределения. Готовый метод даёт тот же результат и заодно сокращает код.

# %%
from matplotlib import pyplot as plt
from scipy.stats import binom

n = 26 # количество попыток
p = 0.9 # вероятность успеха

distr = []

for k in range(0, n + 1):
    current_value = binom.pmf(k, n, p)
    distr.append(current_value)
    
plt.bar(range(0, n + 1), distr)
# Out:
# <BarContainer object of 27 artists>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from matplotlib import pyplot as plt
from math import factorial

p = 1 / 5 #  какова вероятность заключить контракт?
n = 30 # со сколькими компаниями начинаем переговоры?

distr = [] # создайте список distr, 
# в котором будете хранить значения распределения

for k in range(0, n + 1):
    choose = factorial(n) / (factorial(k) * factorial(n - k))
    prob = choose * p ** k * (1-p)**(n-k)
    distr.append(prob) # постройте распределение вероятностей
    
plt.bar(range(0, n + 1), distr); # постройте гистограмму распределения вероятностей

# %% [markdown]
# Если начать переговоры с30 медиа, то 6 — наиболее вероятный результат. Однако слишком велика вероятность, что успехов будет меньше. На гистограмме видно, что в диапазоне от 0 до 5 успехов примерно половина всего распределения. Риск неприемлемо велик.
# ![image.png](attachment:image.png)

# %%
from matplotlib import pyplot as plt
from math import factorial

p = 1/5
n = 45

distr = []

for k in range(0, n + 1):
    choose = factorial(n) / (factorial(k) * factorial(n-k))
    prob = choose * p**k * (1 - p)**(n - k) 
    distr.append(prob)
    
plt.bar(range(0, n + 1), distr);

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from matplotlib import pyplot as plt
from math import factorial

p = 1/5
n = 60

distr = []

for k in range(0, n + 1):
    choose = factorial(n) / (factorial(k) * factorial(n - k))
    prob = choose * p**k * (1-p)**(n-k) 
    distr.append(prob)
    
plt.bar(range(0, n + 1), distr);

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Задача 2
# Питон Петя решил после питонопитомника поступить в питоноакадемию.
# Для этого ему надо сдать шесть разных (не зависящих друг от друга) экзаменов.
# Петя думает, что он отлично подготовился: вероятность завалить каждый из этих экзаменов, судя по пробным вариантам, для него равна 15 %.
# Постройте распределение вероятностей для случайной величины «количество заваленных Петей экзаменов» и гистограмму для неё.

# %%
from matplotlib import pyplot as plt
from math import factorial

n_exams = 6 # напишите ваш код здесь: сколько экзаменов надо сдать?
failure_rate = 15 / 100 # напишите ваш код здесь: какова вероятность завалить один экзамен?

distr = [] # создайте список distr, в котором будете хранить значения распределения

for k in range(0, n_exams + 1):
    # посчитайте кол-во вариантов выбрать k из n_exams
    choose = factorial(n_exams) / (factorial(k) * factorial(n_exams - k))
    # посчитайте вероятность
    prob = choose * failure_rate**k*(1-failure_rate)**(n_exams - k)
    # добавьте очередную вероятность prob в список distr             
    distr.append(prob)   
    
# построение гистограммы распределения вероятностей
plt.bar(range(0, n_exams + 1), distr);

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Непрерывное равномерное и нормальное распределения
# Для  непрерывных случайных величин задают функцию плотности вероятности, по которой можно рассчитать вероятность того, что случайная величина попадёт в нужный промежуток.
# ![image.png](attachment:image.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### Нормальное распределение
# Многие случайные величины распределены так:
#  - Средние значения и значения около них встречаются с высокой вероятностью.
#  - Чем дальше от среднего, тем меньше вероятность встретить такое значение.
#  - Вероятность очень маленьких или очень больших значений мала, но есть.
#
# Формально такое распределение называется нормальным, оно описывает непрерывные случайные величины, и график его плотности вероятности выглядит так:
# ![image-3.png](attachment:image-3.png)
# Природу нормального распределения можно объяснить теоремой, которая неформально звучит так: «Много одинаковых независимых случайных величин, сложенных вместе, дают близкое к нормальному распределение».

# %% [markdown]
# #### Параметры нормального распределения
# Нормальное распределение определяют два параметра — среднее и дисперсия:
# ![image.png](attachment:image.png)
# На графике параметры можно отобразить так:
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# На графике видна закономерность: чем больше значение σ, тем шире распределение. Чем меньше стандартное отклонение, тем распределение уже, а значит, больше вероятность найти случайную величину близко к ожидаемому — центральному — значению.
# Изменение параметра μ сдвигает колокол влево или вправо.

# %% [markdown]
# #### Правило трёх сигм
# Если отметить целое число стандартных отклонений от центра графика, вероятности попасть в получившиеся интервалы не меняются.![image-2.png](attachment:image-2.png)
# Эта закономерность называется правилом трёх сигм:
# 💡 **Почти 100 % всех значений попадают в пределах трёх стандартных отклонений от математического ожидания.**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# слева-направо:распределение Бернулли, биноминальное распределение, равномерное непрерывное рапспределение, нормальное распределение.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Функция нормального распределения
# Типичная задача для известного распределения — найти вероятность того, что случайная величина, следующая этому распределению, попадёт в тот или иной интервал.
# Решать такие задачи помогает функция распределения, или кумулятивная функция распределения.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### пакет `scipy.stats: norm() и cdf()`
# Рассчитать значения функции нормального распределения в Python помогут методы из пакета `scipy.stats: norm() и cdf()`.
# Слово norm в именах методов означает «нормальное распределение» (от англ. normal distribution).
#  - Метод `norm()` задаёт нормальное распределение. На вход он получает два аргумента: математическое ожидание и стандартное отклонение.
#
# Аббревиатура cdf расшифровывается как cumulative distribution function, что переводится как «кумулятивная функция распределения».
#  - Метод `cdf()` получает на вход один аргумент и возвращает вероятность, что случайная величина примет значение, меньшее заданного аргумента.

# %%
from scipy import stats as st

# математическое ожидание
mu = 1000
# стандартное отклонение
sigma = 100

# задаём нормальное распределение с математическим ожиданием 1000 
# и стандартным отклонением 100
distr = st.norm(mu, sigma) 

# значение, для которого хотим найти вероятность
x = 1000

# считаем вероятность получить значение, равное x или меньше 
result = distr.cdf(x)

print('вероятность получить значение, равное x или меньше:', result)
# Out:
# вероятность получить значение, равное x или меньше: 0.5

# %%
from scipy import stats as st

# математическое ожидание
mu = 1000
# стандартное отклонение
sigma = 100

# задаём нормальное распределение с математическим ожиданием 1000 
# и стандартным отклонением 100
distr = st.norm(mu, sigma) 

# значение, для которого хотим найти вероятность
x = 1150

# считаем вероятность получить значение больше x
result = 1 - distr.cdf(x)
print('Вероятность получить значение больше x, иным словом \n\
вероятность правого «хвоста»', result,'или', round(result*100, 1), '%.')
# Out:
# Вероятность получить значение больше x, иным словом
# вероятность правого «хвоста» 0.06680720126885809 или 6.7 %.

# %% [markdown]
# ### Вероятность попадания в конечный интервал
# Функция распределения помогает решить ещё и такую задачу: найти вероятность, что случайная величина попадёт в конечный интервал.
# Чтобы рассчитать вероятность, что случайная величина попадёт в интервал, нужно:
#  - Найти кумулятивную вероятность меньшего значения.
#  - Найти кумулятивную вероятность большего значения.
#  - Вычесть из большей вероятности меньшую. «Хвост» распределения левее меньшего значения сократится и останется только интервал между значениями.
#  ![image.png](attachment:image.png)

# %%
from scipy import stats as st

mu = 1000
sigma = 100

distr = st.norm(mu, sigma) 

x1 = 900
x2 = 1100

result = distr.cdf(x2) - distr.cdf(x1)

print('Вероятность того, что случайная величина попадёт\
между 900 и 1100 равна:\n',result, 'или', round(result*100, 1), '%.')
# Out:
# Вероятность того, что случайная величина попадётмежду 900 и 1100 равна:
#  0.6826894921370859 или 68.3 %.

# %% [markdown]
# Вероятность, что нормально распределённая случайная величина попадёт в пределах одного стандартного отклонения от центра, примерно равна 68.3%.
#
# Задача
# ![image.png](attachment:image.png)
# Какова вероятность, что:
#  - 1) Случайно взятый студент получит грамоту?
#  - 2) Случайно взятый студент получит грамоту, но не получит медаль?
#  - 3) Случайно взятый студент получит и грамоту, и медаль?
#
# Выведите ответы на вопросы в разных строках.
# Перед тем как построить распределения и рассчитать вероятности, приведите параметры распределения и пороговые значения к одной единице измерения — сантиметрам.

# %%
from scipy import stats as st
#нормальное распределение с нужными параметрами N(mu, sigma ) 16900см2=1.69м2
mu = 720
sigma = 16900**0.5 # извлечем корень

distr = st.norm(mu, sigma)  

# значения случайной величины-пороги длин броска для получения грамот и медалей
x1 = 735 
x2 = 750
# вероятность бросить мяч дальше 735 (получить значения больше х1)
result_1 = 1 - distr.cdf(x1) 
# вероятность бросить мяч от 735 до 750 и получить медаль и грамоту
# или получим разницу из вероятности получить меньше х2 и получить меньше х1
# получим промежуток между х2 и х1
result_2 = distr.cdf(x2) - distr.cdf(x1)  
result_3 = 1 - distr.cdf(x2)

print('Вероятность получить грамоту:', result_1, 'или\
', round(result_1*100, 1), '%.') 

print('Вероятность получить грамоту без медали:', result_2, 'или\
', round(result_2*100, 1), '%.')

print('Вероятность получить медаль:', result_3, 'или\
', round(result_3*100, 1), '%.')
# Out:
# Вероятность получить грамоту: 0.4540701363287163 или 45.4 %.
# Вероятность получить грамоту без медали: 0.04532309314702598 или 4.5 %.
# Вероятность получить медаль: 0.4087470431816903 или 40.9 %.

# %% [markdown]
# ## Стандартное нормальное распределение и стандартизация
# Среди всех нормальных распределений есть одно особенное, его называют стандартным.
#
# Стандартное нормальное распределение — это нормальное распределение с математическим ожиданием, равным 0, и стандартным отклонением, равным 1. Его принято обозначать Z ![image.png](attachment:image.png)
#
# Любое нормальное распределение можно с помощью простых арифметических операций привести к стандартному. Такое преобразование называют стандартизацией.
#
# Z-значение — это количество стандартных отклонений, на которое некоторое число отклонилось от центра нормального распределения.
#
# Расчёт Z-значений позволяет сравнить, на сколько значения случайных величин с разными нормальными распределениями отклонились от своих математических ожиданий.
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# Найдём этот процент. Используем метод cdf().

# %%
from scipy import stats as st

# зададим нормальное распределение для школьниц:
mu_F = 3.5
sigma_F = 0.7
distr_F = st.norm(mu_F, sigma_F) 

# зададим нормальное распределение для школьников:
mu_M = 3.9
sigma_M = 0.5
distr_M = st.norm(mu_M, sigma_M) 

#найденная пороговая длина прыжка a, за прыжок дальше которой выдаётся сертификат:
a = 4.9

# найдём и выведем на экран вероятности правых хвостов для a,
# округлив их до 5 цифр после запятой:
print('Вероятность того, что случайная школьница получит сертификат:\
', round(1- distr_F.cdf(a),5), 'или', round((1- distr_F.cdf(a)) * 100,2), '%')
      
print('Вероятность того, что случайный школьник получит сертификат:\
', round(1- distr_M.cdf(a), 5), 'или', round((1- distr_M.cdf(a))* 100,2), '%')
# Out:
# Вероятность того, что случайная школьница получит сертификат: 0.02275 или 2.28 %
# Вероятность того, что случайный школьник получит сертификат: 0.02275 или 2.28 %

# %% [markdown]
# ### Percent Point Function для нормального распределения
# В Python функцию распределения рассчитывают с помощью метода cdf().
# Функция распределения помогает определить вероятность, что случайная величина попадёт в левый «хвост» графика плотности вероятности. Но что, если задача стоит наоборот: распределение вероятности известно, и нужно найти значение, которое отсекает именно такой «хвост»? Например:
#  - Время торможения беспилотного автомобиля при обнаружении препятствия распределено нормально. За какое время успеет остановиться беспилотный автомобиль с вероятностью 99 %?
#  - Масса взрослых питонов подчиняется нормальному распределению. Кран какой грузоподъёмности сможет поднять 85% питонов?
#  - Время собеседования нового кандидата подчиняется нормальному распределению. Сколько времени в календаре стоит выделить HR-специалисту на собеседование, чтобы его хватило для 90 % кандидатов?
#  - Известно, что для лампочки накаливания время работы до перегорания распределено нормально. Сколько часов случайная лампочка будет гореть, не перегорая, с вероятностью 80 %?
#  - В этих задачах известно распределение вероятности, задана вероятность и нужно найти значение x, при котором F(x) примет именно такое значение. Решить эту задачу помогает специальная функция —PPF.
#
# Аббревиатура PPF расшифровывается как percent point function и переводится с англ. как «функция процентных значений». Если даны распределение и вероятность, то эта функция вернёт значение, которое отсекает левый «хвост», соответствующий этой вероятности.
# На той же иллюстрации покажем, как работают функции cdf и ppf — они обратны друг другу:
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy import stats as st

distr = st.norm(1234, 56) 

x_0 = 1234 + 56

result = distr.cdf(x_0)
print(result)
# Out:
# 0.8413447460685429

# %%
# еперь проведём обратную операцию — для того же распределения найдём значение, 
# функция вероятности для которого равна 0.8413447460685429
# Используем для этого метод ppf():

from scipy import stats as st

distr = st.norm(1234, 56) 

p = 0.8413447460685429

result = distr.ppf(p)
print(result)
# Out:
# 1290.0

# %% [markdown]
# Посмотрим, как нашу новую знакомую PPF применяют на практике. Решим задачу!
# ![image.png](attachment:image.png)

# %%
from scipy import stats as st

distr = st.norm(1200, 80) 

p = 0.2

result = distr.ppf(p)
print(' с вероятностью 80%случайная лампочка продержится дольше, \
чем', round(result, 1), 'часов.')
# Out:
#  с вероятностью 80%случайная лампочка продержится дольше, чем 1132.7 часов.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy import stats as st

mu = 420 # среднее значение распределения
sigma = 65 # стандартное отклонение распределения
prob = 0.9 # с какой вероятностью нужно распродать весь товар

distr = st.norm(mu, sigma) # создайте требуемое распределение

n_shipment = distr.ppf(1-prob) # методом ppf, сколько единиц товара нужно заказать 

print('Нужно заказать единиц товара:', int(n_shipment))
# Out:
# Нужно заказать единиц товара: 336

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from scipy import stats as st

mu = 2400 # среднее значение распределения
sigma = 320 # стандартное отклонение распределения
#В переменную threshold сохраните долю заказов, которая должна быть 
# дороже двух стоимостей доставки.
threshold = 3 / 4 

# требуемое распределение
distr = st.norm(mu, sigma) 
# какую максимальную стоимость доставки можно установить
# узначем сколько дешевле двух стоиомстей заказов и разделим на 2
max_delivery_price = distr.ppf(1-threshold) / 2 

print('Максимальная стоимость доставки курьером:\
', round(max_delivery_price), 'руб.')
# Out:
# Максимальная стоимость доставки курьером: 1092 руб.

# %% [markdown]
# Какой метод поможет решить задачу? Подберите подходящее решение.
#  - Погрешность измерения распределена нормально. Нужно найти вероятность, с которой погрешность следующего измерения не превысит заданного значения. Так как - Нужно найти вероятность, с этим помогает CDF.
#  - Вес куриных яиц на птицефабрике распределён нормально. Нужно найти вес, тяжелее которого окажется треть яиц в следующей партии. Так как - Пороговое значение вероятности известно. Нужно найти значение случайной величины, соответствующее этой вероятности. С этим поможет PPF.
#  - Урожай груш с одного дерева, распределён нормально. Нужно найти, с какой вероятностью случайно выбранное дерево принесёт больше ста плодов. Так как - Нужно найти вероятность, с этим помогает CDF.
#  - Длина взрослых черепах распределена нормально. Для маркировки подойдут черепахи длиннее 6/10 всех в популяции. Нужно найти минимальную длину подходящей особи. так как: нужно найти минимальную длину, то есть значение случайной величины  - значит, поможет PPF.

# %% [markdown]
# ### Распределение Пуассона
# ![image.png](attachment:image.png)
# Распределение, которое описывает вероятности возможного числа событий в таких процессах, называют распределением Пуассона.
#
# ✔️ В каких случаях работает распределение Пуассона:
# Происходит некоторый процесс, обычная интенсивность которого известна.
# События — реализации этого процесса — происходят независимо друг от друга (как и успехи в экспериментах по схеме Бернулли в биномиальном распределении).
#
# Распределение Пуассона задаётся единственным параметром — интенсивностью процесса. Она показывает, сколько обычно событий происходит за некоторый промежуток времени. Интенсивность обозначают λ (лямбда).
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### График распределения Пуассона метод poisson.pmf()
# Построим график распределения вероятностей увидеть k сияний за неделю для первых 20 значений:

# %%
import matplotlib.pyplot as plt
from math import factorial, exp
 
# параметр лямбда (используем lmbd, так как lambda зарезервировано в Python):
lmbd = 3
 
distr = []
# для всех чисел от 0 до 19
for k in range(20):
    # рассчитаем вероятности по формуле распределения Пуассона:
    p = (lmbd ** k) / (factorial(k) * exp(lmbd))
    distr.append(p)
 
# зададим график из полученных значений с о-образными точками синего цвета
plt.plot(range(20), distr, 'bo')
# используем числа от 0 до 19 как подписи для горизонтальной оси:
plt.xticks(range(20))
# отобразим график:
plt.show()

# %% [markdown]
# На графике вероятности значений 2 и 3 тоже оказались равны.
# Видно, что для значений с 11 и более вероятность очень близка к нулю. Действительно, наблюдать такое количество сияний уже маловероятно.
#
# Чтобы получить вероятности распределения Пуассона, вместо расчёта непосредственно по формуле можно использовать `метод poisson.pmf()` из модуля scipy.stats.
#
# Аббревиатуру pmf вы уже встречали в уроке про биномиальное распределение. Напомним, она расшифровывается как probability mass function — функция для дискретных распределений, показывающая, какое значение какой вероятностью обладает.
#
# Изменим код: импортируем from scipy.stats import poisson и заменим p = (lmbd ** k) / (factorial(k) * exp(lmbd)) на p = poisson.pmf(k, lmbd). Получится тот же график.

# %%
import matplotlib.pyplot as plt
from scipy.stats import poisson
 
# параметр лямбда:
lmbd = 3
 
distr = []
# для всех чисел от 0 до 19
for k in range(20):
    # рассчитаем вероятности этого значения с помощью метода pmf():
    p = poisson.pmf(k, lmbd)
    distr.append(p)
 
# зададим график из полученных значений с о-образными точками синего цвета
plt.plot(range(20), distr, 'bo')
# используем числа от 0 до 19 как подписи для горизонтальной оси:
plt.xticks(range(20))
# отобразим график:
plt.show()

# %% [markdown]
# #### Функция распределения Пуассона  метод: poisson.cdf()
#
# В модуле scipy.stats есть ещё один `метод: poisson.cdf()`. Он выдаёт значения функции распределения для распределения Пуассона, то есть суммарную вероятность значений от 0 до заданного.
#
# Построим с его помощью график функции вероятности для того же распределения с параметром λ=3. Отобразим значения функции вероятности для первых 20 целых значений, на которых определено распределение Пуассона.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# параметр лямбда:
lmbd = 3

distr = []
# для значений от 0 до 19
for x in range(20):
    # найдём кумулятивные вероятности
    d = poisson.cdf(x, lmbd)
    distr.append(d)

# зададим график из полученных значений с о-образными точками синего цвета
plt.plot(range(20), distr, 'bo')
# используем значения от 0 до 19 как подписи для горизонтальной оси:
plt.xticks(range(20))
# отобразим график:
plt.show()

# %% [markdown]
# Кумулятивная вероятность помогает находить «хвосты» распределения. Для распределения Пуассона это ответы на вопросы типа «какова вероятность, что за промежуток времени произойдёт меньше (или больше) заданного числа событий?»

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy.stats import poisson

# минимальное необходимое количество:
min_num = 50
# количество дней в июне, июле и августе:
days = 30 + 31 + 31 
# рассчитаем параметр лямбда для этого количества дней:
weeks = days / 7 
lmbd = 4 * weeks
# параметр лямбда может получиться нецелым, это допустимо

print(f'Вероятность правого "хвоста" распределения Пуассона от {min_num}',
      f'при lambda={round(lmbd,1)} равна {1 - poisson.cdf(min_num - 1, lmbd)}'
)
# Out:
# Вероятность правого "хвоста" распределения Пуассона от 50 при lambda=52.6 равна 0.657101690371793

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from scipy.stats import poisson

guests_threshold = 7 # укажите лимит посетителей
# в среднем каждые четыре минуты в кафе заходит посетитель
# Промежуток времени, который нас интересует 20 минут. 
# посетителей в среднем 20/4 = 5 человек это лямбда
lmbd = 20/4 # укажите или рассчитайте параметр лямбда

print(1-poisson.cdf(guests_threshold, lmbd)) # выведите на экран получившуюся вероятность
print(f'За месяц из 30 дней можно \
ожидать {round(30*(1-poisson.cdf(guests_threshold, lmbd)))} дня с включением \
дополнительного электрогриля.')
# Out:
# 0.1333716740700075
# За месяц из 30 дней можно ожидать 4 дня с включением дополнительного электрогриля.

# %% [markdown]
# ### о распределении Пуассона:
# В модуле scipy.stats есть метод poisson.pmf() для получения вероятностей распределения Пуассона и метод poisson.cdf() для получения значений его функции распределения.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Аппроксимации
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Аппроксимация биномиального распределения распределением Пуассона

# %% [markdown]
# Аппроксимация (лат. approximatis — поблизости) — это математический термин для приближения. Аппроксимировать — значит найти значения, близкие к интересующим исследователя.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom, poisson
 
# задаем параметры биномиального распределения
n = 10
p = 0.8
 
# считаем параметр распределения Пуассона для аппроксимации
lmbd = n * p
 
# задаем диапазон значений k для построения графика
max_value = 10
 
binom_probs = []
poisson_probs = []
# для всех значений от 0 до 10
for k in range(max_value + 1):
    # рассчитываем значения вероятности для биномиального распределения
    # и распределения Пуассона
    binom_prob = binom.pmf(k, n, p)
    poisson_prob = poisson.pmf(k, lmbd)
    # добавляем в соответствующие списки
    binom_probs.append(binom_prob)
    poisson_probs.append(poisson_prob)
 
# рисуем графики
plt.plot(range(max_value + 1), binom_probs, 'bo',
         label=f'Биномиальное распределение с n={n} и p={p}')
plt.plot(range(max_value + 1), poisson_probs, 'rd',
         label='Аппроксимация распределением Пуассона')
plt.xlabel(f'k: количество успехов для B{n, p} / событий для Pois({lmbd})')
plt.ylabel('Вероятность k')
plt.legend()
plt.xticks(range(max_value + 1))
plt.show()
 
# найдем суммарную ошибку аппроксимации для соответствующих значений:
error_values = []
for i in range(max_value + 1):
    error = abs(binom_probs[i] - poisson_probs[i])
    error_values.append(error)
 
print('Средняя разница вероятностей на значение:\
', sum(error_values) / len(error_values))
print('Максимальная разница вероятностей:', max(error_values))
# Out:
# Средняя разница вероятностей на значение: 0.051737727210386296
# Максимальная разница вероятностей: 0.16240335604940329

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom, poisson
 
# задаём параметры биномиального распределения
n = 1000
p = 0.01
 
# считаем параметр распределения Пуассона лямбда для аппроксимации
lmbd = n * p
 
# задаём диапазон значений k для построения графика:
# добавим к мат.ожиданию биномиального распределения 4 стандартных отклонения
std_binom = np.sqrt(n * p * (1 - p))
max_value = int(n * p + 4 * std_binom)

binom_probs = []
poisson_probs = []
# для всех значений от 0 до max_value
for k in range(max_value + 1):
    # рассчитываем знач.вероятности для биномиального распр. и распр. Пуассона
    binom_prob = binom.pmf(k, n, p)
    poisson_prob = poisson.pmf(k, lmbd)
    # добавляем значения в соответствующие списки
    binom_probs.append(binom_prob)
    poisson_probs.append(poisson_prob)
 
# рисуем графики
plt.plot(range(max_value + 1), binom_probs, 'bo', label=f'Биномиальное \
распределение с n={n} и p={p}')
plt.plot(range(max_value + 1), poisson_probs, 'rd', label='Аппроксимация \
распределением Пуассона')
plt.xlabel(f'k: количество успехов для B{n,p} / событий для Pois({lmbd})')
plt.ylabel('Вероятность k')
plt.legend()
plt.show()
 
# найдём суммарную ошибку аппроксимации:
error_values = []
for i in range(max_value + 1):
    error = abs(binom_probs[i] - poisson_probs[i])
    error_values.append(error)
 
print('Средняя разница вероятностей на значение:\
', sum(error_values) / len(error_values))
# Out:
# Средняя разница вероятностей на значение: 0.00021270660527640802

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from scipy.stats import poisson

threshold = 70
lmbd_5 = 60
lmbd_8 = 96

print('Вероятность для пяти часов:', 1 - poisson.cdf(threshold - 1, lmbd_5))
print('Вероятность для восьми часов:', 1 - poisson.cdf(threshold - 1, lmbd_8))
# Out:
# Вероятность для пяти часов: 0.11178964695883675
# Вероятность для восьми часов: 0.9976588561499148

# %% [markdown]
# Аппроксимация распределением Пуассона в этой задаче поможет, например, выбрать, сколько показов баннера и на какое время закупать, если компания знает, сколько кликов хочет получить.

# %% [markdown]
# ### Аппроксимация биномиального распределения нормальным
# еперь сформулируем условие хорошей аппроксимации:
# Нужно взять промежуток от математического ожидания биномиального распределения плюс-минус три его стандартных отклонения. Если он лежит в пределах [0,n] (то есть там, где биномиальное распределение определено), то его форма будет симметрична и близка к нормальному распределению.
# ![image.png](attachment:image.png)

# %%
from math import sqrt
import matplotlib.pyplot as plt
from scipy.stats import binom, norm
 
# зададим функцию, которая выдаёт <num> чисел,
# равномерно распределённых от <start> до <stop>
# (понадобится для визуализации нормального распределения)
def linspace(start, stop, num):
    step = (stop - start) / (num - 1)
    result = []
    for i in range(num):
        result.append(start + step * i)
    return result
 
# задаём параметры биномиального распределения
n = 50
p = 0.22

# границы промежутка, в котором будем строить аппроксимацию -
# от n*p минус 4 ст.отклонения бином.распределения
# до n*p плюс 4 ст.отклонения бином.распределения
# (там, где вероятности значений почти не равны нулю)
left = int(n * p - 4 * sqrt(n * p * (1 - p)))
right = int(n * p + 4 * sqrt(n * p * (1 - p)))
 
# зададим набор значений биномиальной величины на выбранном промежутке:
# все неотрицательные целые числа от left до right
x = list(range(max(0, left), right))
# рисуем график биномиального распределения
ax = plt.subplot()
# используем синие о-образные маркеры и размер маркера 5
ax.plot(x, binom.pmf(x, n, p), 'bo', ms=5,
	      label='вероятности биномиального распределения')

# зададим мат.ожидание и ст.отклонение нормального распределения равными
# мат.ожиданию и ст.отклонению биномиального распределения
mu = n * p
sigma = sqrt(n * p * (1 - p))
 
# рисуем график нормального распределения:
# получим список из 100 чисел от left до right
x = linspace(left, right, 100)
# используем красную линию ширины 3 и прозрачности 0.3
ax.plot(x, norm.pdf(x, mu, sigma), 'r-', lw=3, alpha=0.3, 
        label='плотность вероятности нормального распределения')
 
# зададим подписи по оси x в пределах ± 3 ст.отклонений от мат.ожидания
# (последний аргумент в методе range - интервал между подписями)
x_ticks = list(range(int(mu - 3 * sigma), int(mu + 3 * sigma), 1))
ax.set_xticks(x_ticks)

# настраиваем оптимальное расположение легенды и выводим график
ax.legend(loc='best')
plt.show()

# выводим, выполняется ли наше условие аппроксимации:
# лежит ли mu ± 3 sigma в промежутке от 0 до n:
if (mu - (3 * sigma) >= 0) and ((mu + (3 * sigma) <= n)):
    print('Условие выполняется')
else:
    print('Условие не выполняется')
# Out:
# Условие выполняется

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from math import sqrt
from scipy import stats as st

# задаём параметры биномиального распределения
n = 45
p = 0.4

# зададим мат.ожидание и ст.отклонение нормального распределения равными
# мат.ожиданию и ст.отклонению биномиального распределения
mu = n * p
sigma = sqrt(n * p * (1 - p))

# задаём нормальное распределение с математическим ожиданием 18 
# и стандартным отклонением ~3.29
distr = st.norm(mu, sigma) 

# границы интервала
y_1 = 15.5
y_2 = 16.5

# считаем вероятность получить значение от y1 до y2
result = distr.cdf(y_2) - distr.cdf(y_1)
print(result)
# Out:
# 0.10062799571522435

# %%
from math import sqrt
from scipy import stats as st

# задаём параметры биномиального распределения
n = 45
p = 0.4

# зададим мат.ожидание и ст.отклонение нормального распределения равными
# мат.ожиданию и ст.отклонению биномиального распределения
mu = n * p
sigma = sqrt(n * p * (1 - p))

# задаём нормальное распределение с математическим ожиданием 18 
# и стандартным отклонением ~3.29
distr = st.norm(mu, sigma) 

# найдём суммарную ошибку аппроксимации:
error_values = []
for i in range(n + 1):
    error = abs(st.binom.pmf(i, n, p) - (distr.cdf(i + 0.5) - distr.cdf(i - 0.5)))
    error_values.append(error)
 
print('Средняя разница вероятностей на значение:', sum(error_values) / len(error_values))
print('Максимальная разница вероятностей:', max(error_values))
# Out:
# Средняя разница вероятностей на значение: 0.0003375151305502594
# Максимальная разница вероятностей: 0.0018872455430816032

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from math import sqrt
from scipy import stats as st

# задаём параметры биномиального распределения
n = 1500000
p = 0.029

# зададим мат.ожидание и ст.отклонение нормального распределения равными
# мат.ожиданию и ст.отклонению биномиального распределения
mu = n * p
sigma = sqrt(n * p * (1 - p))

# задаём нормальное распределение
distr = st.norm(mu, sigma) 

# считаем вероятность хвоста слева от 43 тысяч
result = distr.cdf(43000)
print('Вероятность получить меньше 43000 кликов на 1,5млн показов равна менее\
', round(result * 100,2), '%.\n Т.е. на 43 тысячи кликов можно рассчитывать \
наверняка!')
# Out:
# Вероятность получить меньше 43000 кликов на 1,5млн показов равна менее 0.75 %.
#  Т.е. на 43 тысячи кликов можно рассчитывать наверняка!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from math import sqrt
from scipy import stats as st

n = 550000 # задайте параметры 
p = 11.4 / 100 # биномиального распределения

mu = n * p # рассчитайте параметры 
sigma = sqrt(n * p * (1 - p)) # нормального распределения

distr = st.norm(mu, sigma) # задайте нормальное распределение

result = 1 - distr.cdf(63000) # найдите вероятность
print('Вероятность того, что в следующем месяце в соцсети \nпоявится больше\
 63 тысяч новых аккаунтов равна', round(result * 100,2), '%.')
# Out:
# Вероятность того, что в следующем месяце в соцсети
# появится больше 63 тысяч новых аккаунтов равна 10.15 %.

# %% [markdown]
# #### Ошибка аппроксимации
# Чем симметричнее распределение Пуассона, тем точнее его аппроксимирует нормальное. При выполнении условия аппроксимации распределение Пуассона достаточно симметрично, и ошибка аппроксимации мала.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
