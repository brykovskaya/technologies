# %% [markdown]
# бывает, что количество исходов бесконечно. Также исходы в экспериментах необязательно представлены числами — это могут быть слова, например: «Кот выбрал корм с лососем».
#
# Если исходов много и их нельзя описать математически, пользоваться предыдущей теорией с экспериментами и исходами сложно. Чтобы описывать и анализировать такие ситуации, вам предстоит познакомиться с новой терминологией. Её придумали математики, и главное понятие в ней — случайная величина.
# ### Случайная величина
# Случайная величина — переменная, которая хранит исход некоторого случайного эксперимента в виде числа. В результате эксперимента случайная величина может принимать только одно значение.
#
# В случайной величине исход обязательно представлен числом. Поэтому случайную величину проще анализировать математикам.
#
# если исходы описаны словами, самостоятельно определим значение для каждого исхода:
#
#  - Исход «Кот выбрал корм с лососем» кодируем значением 1. Это значит, что кот выбрал первый корм — с лососем.
#  - Исход «Кот выбрал корм с тунцом» кодируем значением 2. Это значит, что кот выбрал второй корм — с тунцом.

# %% [markdown]
# ### Таблица распределения случайной дискретной величины
#
# Случайная величина может быть как дискретной, так и непрерывной.
#
# Таблица распределения случайной дискретной величины — это таблица, которая хранит все значения, которые может принимать случайная величина, и вероятности, с которыми она эти значения принимает.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Вероятность попасть в промежуток для дискретной случайной величины
# ![image.png](attachment:image.png)

# %% [markdown]
# Из правила следует, что сумма всех значений вероятностей в таблице распределения должна быть равна 1. Ведь вероятность того, что случайная величина примет какое-либо значение из набора, должна быть равной 1, так как это является достоверным событием — таким, которое обязательно произойдёт.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Кумулятивная функция для дискретной случайной величины
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# По определению, кумулятивная функция в точке показывает вероятность того, что случайная величина приняла значение левее этой точки. С этим связано несколько свойств функции, которые обязательно должны выполняться:
#  - Кумулятивная функция не убывает. Она может либо не изменяться, либо возрастать. Это происходит потому, что вероятность не может быть отрицательной. Если мы добавляем новые значения к диапазону, то вероятность в них попасть или положительна, или равна нулю. Благодаря этому, когда мы добавляем эту вероятность к значениям кумулятивной функции, мы можем получить или такое же значение, или большее.В примере с кафе вероятность того, что посетитель придёт в некоторый час не может быть отрицательной. Поэтому кумулятивная функция не может убывать: она может либо увеличиться, либо не меняться вообще.
#  - Кумулятивная функция начинается из 0. Она показывает вероятность того, что значение случайной величины будет левее некоторого значения. Если мы возьмём минимальное возможное значение случайной величины, то вероятность попасть левее будет равна 0, а значит, кумулятивная функция будет равна 0.На примере кафе станет понятно, что вероятность того, что посетитель пришёл раньше9, равна0.
#  - Кумулятивная функция приходит в 1. Если мы возьмём максимальное возможное значение случайной величины, вероятность попасть левее будет равна 1, а значит, кумулятивная функция равна 1.
#
# Допустим, мы точно уверены, что за день к нам придёт хотя бы один посетитель. Поэтому вероятность того, что посетитель придёт до 18 часов (в это время кафе закрывается), равна 1.

# %% [markdown]
# ### Математическое ожидание дискретной случайной величины
# Характеристики случайной величины описывающие центр и разброс случайной величины: это математическое ожидание и дисперсия. Рассмотрим   мат.ожидание.
#
#
# ![image.png](attachment:image.png)
#
#
# по этой формуле нужно просто найти сумму всех произведений вероятности значения на само значение из таблицы распределения.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **Математическое ожидание — важная концепция в анализе случайных величин. Оно позволяет понять, к чему приближается среднее значение случайной величины в случае, если повторений будет бесконечно много.**
#
# среднее значение никогда не будет равно математическому ожиданию, а будет только приближаться к нему (закон больших чисел). ожидают, что среднее будет ей равно, но проверить это на практике невозможно.

# %% [markdown]
#  утверждения о связи математического математического ожидания, среднего и закона больших чисел:
#   - Среднее значение случайной величины будет стремиться к её математическому ожиданию при бесконечном числе повторений.
#   - Связь между математическим ожиданием и средним значением случайной величины обоснована законом больших чисел.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Вывод — в случае равновероятных исходов формула математического ожидания превращается в формулу среднего для
# n
# n значений.

# %% [markdown]
# ### Дисперсия дискретной случайной величины
# характеристика разброса случайных величин- дисперсия.
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# у дисперсии есть «младший брат» — стандартное отклонение, которое равно корню из дисперсии.
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# вторая формула дисперсии:
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Свойства математического ожидания и дисперсии случайной величины
# ![image.png](attachment:image.png)

# %% [markdown]
# Акция со вторым кофе принесла много новых посетителей. Через месяц её решили повторить. Мы прогнозируем, что в первый день число посетителей увеличится на 15, а во второй день — в 5 раз. Как тогда изменятся характеристики случайной величины X: «Число посетителей за день»? Выберите верные варианты.
#  - в первый день математическое ожидание увеличится на 15, а дисперсия не изменится.
#  - Во второй день акции математическое ожидание увеличится в 5 раз, а дисперсия — в 25 раз
